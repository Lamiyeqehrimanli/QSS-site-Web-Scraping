# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://www.qss.az/trainings'
response = requests.get(url)
trainings_soup =  BeautifulSoup(response.text, 'html.parser')

# %%
trainings_soup    #Saytin butun html kodlarini verdi
# Out:
# <!DOCTYPE html>
#
# <html lang="az">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>Təlimlər
# </title>
# <link href="/css/style.css" rel="stylesheet"/>
# <link href="/favicon1.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
# <link href="/favicon1.ico" rel="icon" type="image/x-icon"/>
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
#             var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
#             (function(){
#                 var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
#                 s1.async=true;
#                 s1.src='https://embed.tawk.to/5c88a331101df77a8be252c4/default';
#                 s1.charset='UTF-8';
#                 s1.setAttribute('crossorigin','*');
#                 s0.parentNode.insertBefore(s1,s0);
#             })();
#         </script>
# <!--End of Tawk.to Script-->
# <!-- Facebook Pixel Code -->
# <script>
#             !function(f,b,e,v,n,t,s)
#             {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                 n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                 if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                 n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];
#                 s.parentNode.insertBefore(t,s)}(window, document,'script',
#                 'https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '347737425851755');
#             fbq('track', 'PageView');
#         </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=347737425851755&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </link></link></head>
# <body class="trd-home-template">
# <!-- HEADER -->
# <header class="trd-header">
# <!-- Topbar -->
# <div class="trd-header-topbar">
# <div class="container">
# <div class="row">
# <!-- contact info -->
# <div class="trd-contact-infos">
# <ul>
# <li class="trd-header-info-phn">+994 51 341 4340</li>
# <li class="trd-header-info-location">Aşıq Alı 2A, Nərimanov rayonu</li>
# </ul>
# </div>
# <!-- End -->
# <!-- Social Links -->
# <div class="trd-social-links">
# <ul>
# <li class="trd-fb-icon">
# <a href="https://www.facebook.com/QSSAnalytics/" target="_blank">
# <i class="fa fa-facebook"></i>
# </a>
# </li>
# <li class="trd-linkedin-icon">
# <a href="https://www.linkedin.com/company/quality-statistics-society" target="_blank">
# <i class="fa fa-linkedin"></i>
# </a>
# </li>
# </ul>
# </div>
# <!-- End -->
# </div>
# </div>
# </div>
# <!-- End -->
# <!-- Bottombar -->
# <div class="trd-header-bottombar">
# <!-- Navigation Menu start-->
# <nav class="navbar trd-main-menu" role="navigation">
# <div class="container">
# <div class="row">
# <!-- Navbar Toggle -->
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <!-- Logo -->
# <a class="navbar-brand" href="/"><img alt="TRADE" class="logo" src="/images/1.png"/></a>
# </div>
# <!-- Navbar Toggle End -->
# <!-- navbar-collapse start-->
# <div class="navbar-collapse trd-menu-wrapper collapse padding0" id="nav-menu" role="navigation">
# <!-- Menu -->
# <ul class="nav navbar-nav trd-menus">
# <li>
# <a href="/">Əsas</a>
# </li>
# <li>
# <a href="/for-business">Xidmətlərimiz</a>
# <ul class="trd-dropdown-menu dropdown-menu-media-services">
# <li>
# <a href="/for-business">Bizneslər üçün</a>
# </li>
# <li>
# <a href="/for-science">Elmi Tədqiqatlar və Akademik Təşkilatlar üçün</a>
# </li>
# <li>
# <a href="/for-gov">Dövlət Qurumları və Qeyri-hökumət Təşkilatları üçün  </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/trainings">Təlimlərimiz</a>
# </li>
# <li>
# <a href="/about-ti">T&amp;I Mərkəzi</a>
# </li>
# <li>
# <a href="/about-us">Haqqımızda</a>
# <ul class="trd-dropdown-menu">
# <li>
# <a href="/about-us#biz-kimik">Biz kimik ?</a>
# </li>
# <li>
# <a href="/about-us#biz-ne-edirik">Biz nə edirik ?</a>
# </li>
# <li>
# <a href="/about-us#komandamiz">Komandamız</a>
# </li>
# <li>
# <a href="/contact-us">Əlaqə</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/blog">Blog</a>
# </li>
# <li>
# <a href="#">Bizə qoşulun</a>
# <ul class="trd-dropdown-menu dropdown-menu-media-last">
# <li>
# <a href="/karyera">Karyera İmkanları</a>
# </li>
# <li>
# <a href="/student-reg">Tələbə üzvlüyü</a>
# </li>
# <li>
# <a href="/cooperation">Əməkdaşlıq</a>
# </li>
# <li>
# <a href="/guest-lecturer">Qonaq mühazirəçi</a>
# </li>
# </ul>
# </li>
# </ul>
# <!-- End -->
# </div>
# <!-- navbar-collapse end-->
# </div>
# </div>
# </nav>
# <!-- Navigation Menu end-->
# </div>
# <!-- End -->
# </header>
# <!-- HEADER END -->
# <section class="trd-page-breadcumb-header">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h1 class="trd-page-title">Təlimlər</h1>
# </div>
# </div>
# </div>
# </section>
# <section id="qss-trainings">
# <div class="container">
# <div class="row">
# <div class="col-xs-12" style="padding: 0; margin-bottom: 25px;">
# <a href="http://dsa.az" target="_blank">
# <img alt="DSA Banner" class="img-responsive" src="http://www.qss.az/images/banner.png"/>
# </a>
# </div>
# </div>
# <div class="row">
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="http://dsa.az" target="_blank">Ətraflı</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="http://dsa.az" target="_blank">
# <img alt="image" src="/uploads/dsa bootcam web-1576582335.png" style="object-fit: cover;">
# </img></a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="http://dsa.az" target="_blank">Data Science Bootcamp</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 120 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/19">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/data-science-giris-telimi">
# <img alt="image" src="/uploads/data science giris telim web-1578291842.png" style="object-fit: cover;">
# </img></a>
# <div class="news-price">
# <h5 class="single-price text-center">Ödənişsiz</h5>
# </div>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/data-science-giris-telimi">Data Science Giriş təlimi </a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Data Science-ın gücünü və bu sahədə ən çox tələb olunan bacarıqları ödənişsiz təlimimizdə bizi...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> </div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/1">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/data-ile-biznes-analitikasi">
# <img alt="image" src="/uploads/dba telim web (1)-1575552012.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/data-ile-biznes-analitikasi">Data ilə Biznes Analitikası</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Data ilə Biznes Analitikasını qısa müddətdə öyrən və daha peşəkar qərarlar ver!
#
# ...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 30 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/22">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/power-bi-excel-sql-ile-data-analitikasi-telimi">
# <img alt="image" src="/uploads/powerbi excel sql telim web (3)-1577095683.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/power-bi-excel-sql-ile-data-analitikasi-telimi">Power BI &amp; Excel &amp; SQL ilə Data An...</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Bilirsinizmi ki, saatlarla üzərində işlədiyiniz Excel data analizi və vizual hesabatları Power BI ilə c�...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 30 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/12">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/power-bi-ile-vizuallasdirma">
# <img alt="image" src="/uploads/power bi telim web-1575640169.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/power-bi-ile-vizuallasdirma">Power BI ilə vizuallaşdırma</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 20 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/20">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/python-ile-data-science">
# <img alt="image" src="/uploads/python telim web-1575552042.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/python-ile-data-science">Python ilə Data Science</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Data Science-də Python-un gücü ilə tanış olun!...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 30 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/8">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/data-analitikasi-sueni-zeka-r-ile">
# <img alt="image" src="/uploads/r telim web (1)-1575640089.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/data-analitikasi-sueni-zeka-r-ile">Data Analitikası (+Süni Zəka) R ...</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Dataya əsaslanaraq daha ağıllı qərarlar verin. Bunun üçün R proqramı optimal seçimdir....</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 30 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/4">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/sehiyye-analitikasi-telimi">
# <img alt="image" src="/uploads/sehiyye analitikasi telimi web-1577082591.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/sehiyye-analitikasi-telimi">Səhiyyə Analitikası Təlimi</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Bu kurs həkimlərin elmi əsaslı nəticələr əldə etmələri üçün Səhiyyə Statistikasını daha rahat ...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 40 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/16">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/sql-ile-data-analitikasi">
# <img alt="image" src="/uploads/sql telim web-1575640216.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/sql-ile-data-analitikasi">SQL ilə Data Analitikası</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Data ilə heç bir çətinliyiniz qalmasın!...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 20 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/10">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/excel-ile-data-analitikasi">
# <img alt="image" src="/uploads/excel telim web-1575896205.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/excel-ile-data-analitikasi">Excel ilə Data Analitikası</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Excel ilə data analitikasına addımla!...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 20 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/2">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/spss-ile-data-analitikasi">
# <img alt="image" src="/uploads/spss telim web-1576305733.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/spss-ile-data-analitikasi">SPSS ilə Data Analitikası</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>SPSS ilə tədqiqat bacarıqlarınızı praktiki olaraq inkişaf etdirin!...</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 40 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# <!-- News block -->
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-12 thumbnail">
# <a class="btn qss-trainings-apply-button btn-success" href="/training/apply/18">Müraciət et</a>
# <div class="news-block">
# <div class="news-image col-lg-12 padding0">
# <a href="/trainings/tableau-ile-vizuallasdirma">
# <img alt="image" src="/uploads/tableau web telim-1576305716.png" style="object-fit: cover;"/>
# </a>
# </div>
# <div class="news-content col-lg-12 padding0">
# <div class="news-title">
# <a href="/trainings/tableau-ile-vizuallasdirma">Tableau ilə Vizuallaşdırma</a>
# </div>
# <div class="news-desc col-lg-12">
# <p>Tableau ilə Datanızın hekayəsini danışın....</p>
# </div>
# <div class="news-desc col-lg-12 col-md-12 col-sm-12 col-xs-12">
# <div class="col-lg-5 col-md-5 col-sm-5 col-xs-5 single-star-b padding0"><i aria-hidden="true" class="fa fa-clock-o"></i> 27 saat</div>
# </div>
# </div>
# </div>
# </div>
# <!-- News block end -->
# </div>
# </div>
# </section>
# <!-- FOOTER -->
# <footer>
# <div class="container">
# <div class="row">
# <!-- Footer Top -->
# <div class="trd-footer-top">
# <!-- About Widget -->
# <div class="col-md-4 col-sm-6 col-xs-12 trd-footer-widget trd-about-widget">
# <div class="trd-logo-wrapper">
# <img alt="Trade" class="img-responsive" src="/images/3.png" style="width: 60%;"/>
# </div>
# <p>Bizim missiyamız ölkəmiz Azərbaycanda Data Analitika və Statistika sahələrinin inkşaf etdirilməsi və təbliğidir. Biz bu məqsədlərə nail olmaq üçün öz biznes xidmətlərimizi və təlimlərimizi təklif edirik.</p>
# </div>
# <!-- End -->
# <!-- Facebook page-->
# <div class="col-md-4 col-sm-6 col-xs-12 trd-footer-widget trd-useful-link-widget">
# <h3 class="trd-footer-widget-title">Facebook</h3>
# <div class="trd-footer-widget-content">
# <div class="fb-page" data-adapt-container-width="true" data-height="70" data-hide-cover="false" data-href="https://www.facebook.com/QSSAnalytics/" data-show-facepile="true" data-small-header="false" data-tabs="timeline">
# <blockquote cite="https://www.facebook.com/QSSAnalytics/" class="fb-xfbml-parse-ignore">
# <a href="https://www.facebook.com/QSSAnalytics/">QSS Analytics</a>
# </blockquote>
# </div>
# </div>
# </div>
# <!--End-->
# <!-- Useful Link Widget -->
# <div class="col-md-4 col-sm-6 col-xs-12 trd-footer-widget trd-useful-link-widget">
# <h3 class="trd-footer-widget-title">Menyu</h3>
# <div class="trd-footer-widget-content">
# <ul>
# <li><a href="/about-us">Haqqımızda</a></li>
# <li><a href="/about-us#komandamiz">Komandamız</a></li>
# <li><a href="/about-us#biz-kimik">Biz kimik ?</a></li>
# <li><a href="/for-business">Xidmətlərimiz</a></li>
# <li><a href="/ti-center">T&amp;I Mərkəzi</a></li>
# <li><a href="/trainings">Təlimlər</a></li>
# <li><a href="/cooperation">Əməkdaşlıq</a></li>
# <li><a href="/contact-us">Əlaqə</a></li>
# </ul>
# </div>
# </div>
# <!-- End -->
# </div>
# <!-- End -->
# </div>
# </div>
# <!-- End -->
# </footer>
# <!-- FOOTER END -->
# <!-- jQuery -->
# <script src="/js/vendors/jquery.min.js"></script>
# <!-- Plugins -->
# <script src="/js/plugins.js"></script>
# <!--Facebook page-->
# <div id="fb-root"></div>
# <script>
#           (function(d, s, id) {
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) return;
#             js = d.createElement(s); js.id = id;
#             js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.8";
#             fjs.parentNode.insertBefore(js, fjs);
#           }(document, 'script', 'facebook-jssdk'));
#         </script>
# <!-- Main JS -->
# <script src="/js/main.js"></script>
# <script>
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#           ga('create', 'UA-93465170-1', 'auto');
#           ga('send', 'pageview');
#
#         </script>
# <!-- Main scripts build from webpack -->
# <!-- <script src="js/scripts.js"></script> -->
# <script type="text/javascript">
#         function showEmailModal () {
#           $("#emailModal").modal('show');
#         }
#           setTimeout(showEmailModal, 3000);
#         </script>
# </body>
# </html>

# %%
fin_names = []
names = trainings_soup.findAll('div',attrs={"class":"news-title"})

# %%
#print(names)

# print -> <div class="news-title"><a href="/trainings/data-science-giris-telimi">Data Science Giriş təlimi </a></div>

# %%
for trainings_name in names:
    fin_names.append(trainings_name.text)
    
#fin_names                                                  
#'\nData Science Giriş təlimi \n',

# %%
t = map(lambda s: s.strip(), fin_names)
telimler = list(t)
print(telimler)
# Out:
# ['Data Science Bootcamp', 'Data Science Giriş təlimi', 'Data ilə Biznes Analitikası', 'Power BI & Excel & SQL ilə Data An...', 'Power BI ilə vizuallaşdırma', 'Python ilə Data Science', 'Data Analitikası (+Süni Zəka) R ...', 'Səhiyyə Analitikası Təlimi', 'SQL ilə Data Analitikası', 'Excel ilə Data Analitikası', 'SPSS ilə Data Analitikası', 'Tableau ilə Vizuallaşdırma']

# %%
trainings = pd.DataFrame(telimler)
#print(trainings)

# %%
trainings_csv = trainings.to_csv('trainings_.csv')

# %%
trainings_csv=pd.read_csv('trainings_.csv')
trainings_csv.head(3)
# Out:
#    Unnamed: 0                            0
# 0           0        Data Science Bootcamp
# 1           1    Data Science Giriş təlimi
# 2           2  Data ilə Biznes Analitikası

# %%
trainings_csv.drop('Unnamed: 0',axis=1).head(3)
# Out:
#                              0
# 0        Data Science Bootcamp
# 1    Data Science Giriş təlimi
# 2  Data ilə Biznes Analitikası

# %%
url = 'http://www.qss.az/trainings'
response = requests.get(url)
trainings_soup =  BeautifulSoup(response.text, 'lxml')
#print(trainings_soup.prettify())
#trainings_soup

# %%
all_names,all_links, all_hours, all_lang = [],[], [], []

for product in trainings_soup.find_all('div',attrs={"news-title"}):
    #print(product.find('a'))                     # <a href="/trainings/data-science-giris-telimi">Data Science Giriş təlimi </a>
    #print(product.find('a').get('href'))          #  /trainings/data-science-giris-telimi
    if(product.find('a').get('href')=='http://dsa.az'):
        continue
    else:
        link = 'http://www.qss.az' + product.find('a').get('href')
        #print(link)                                                  #h ttp://www.qss.az/trainings/data-science-giris-telimi
        names = product.find('a').text
        #print(names)                                                 # Data Science Giriş təlimi 
        r2 = requests.get(link)
        c = r2.content                                                # content azerisirift taniyir text yox ama ekseren text istifade olunur
        #print(c)                                                     # full oxudu ama qarisiq verdi ekrana text kimi
        
        soup2 = BeautifulSoup(c,"html.parser")
        #print(soup2)                                         # full oxudu ekrana html kimi verdi
        hours = soup2.find('h4', attrs={"single-hour"}).text
        #print(hours)                                          # saatlari verdi
        
        language = soup2.find('h4', {'class': 'single-language'}).text
        #print(language)                                                        #dilleri cap edir
        
        #creation = product.find('div', {'class': 'products-created'}).text

    all_links.append(link)
    all_hours.append(hours)
    all_lang.append(language)
    all_names.append(names)


data_list = list(zip(all_names,all_links, all_hours, all_lang))
#print(data_list)

column_names = ['Names','Links', 'Houur','Language']
#print(column_names)

qss = pd.DataFrame(data_list,columns=column_names)
#print(qss)

# %%
qss['Houur'] = qss['Houur'].str[8:]
#print(qss)

# %%
qss['Language'] = qss['Language'].str[5:]
#print(qss)

# %%
qss_csv = qss.to_csv('qss.csv')
qss.head(5)
# Out:
#                                    Names  \
# 0             Data Science Giriş təlimi
# 1            Data ilə Biznes Analitikası
# 2  Power BI & Excel & SQL ilə Data An...
# 3            Power BI ilə vizuallaşdırma
# 4                Python ilə Data Science
#
#                                                Links    Houur         Language
# 0  http://www.qss.az/trainings/data-science-giris...           Azərbaycan dili
# 1  http://www.qss.az/trainings/data-ile-biznes-an...  30 saat  Azərbaycan dili
# 2  http://www.qss.az/trainings/power-bi-excel-sql...  30 saat  Azərbaycan dili
# 3  http://www.qss.az/trainings/power-bi-ile-vizua...  20 saat       Azərbaycan
# 4  http://www.qss.az/trainings/python-ile-data-sc...  30 saat  Azərbaycan dili
